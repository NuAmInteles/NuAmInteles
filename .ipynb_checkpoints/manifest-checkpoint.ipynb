# %%
import os

# %%
os.getcwd()
# Out:
# '/home/dev/repos/nuaminteles/assets'

# %%
os.chdir('..')

# %%
os.listdir()
# Out:
# ['files', 'script', 'words', 'converted']

# %%
os.chdir('converted')

# %%
os.listdir()
# Out:
# ['sase_61688d59-3bfa-4459-9868-e3e2dc45dbdb_3.wav',
#  'trei_2a21b905-0aae-4035-b9e3-9dbd1afc21ab_1.wav',
#  'stinge_lumina_fefb1468-0a02-4848-b5c8-90d1169c07c7_2.wav',
#  'verifica_emailul_ce805d95-7d45-41e9-8cad-9eb92b4febc9_2.wav',
#  'opt_8be0543c-a02b-47a3-b9c3-5f75bc56993c_1.wav',
#  'patru_db73df38-a4fb-4325-a495-a63d4c9a1c7b_1.wav',
#  'cum_este_vremea_6e3047c2-f0b2-4315-a567-0b587b2c9088_2.wav',
#  'zero_ee14487a-3237-4a14-a74f-45331907c1eb_2.wav',
#  'aprinde_lumina_adb7add6-96fb-4cc3-8305-160065310cd2_2.wav',
#  'sase_2a21b905-0aae-4035-b9e3-9dbd1afc21ab_3.wav',
#  'zero_61688d59-3bfa-4459-9868-e3e2dc45dbdb_3.wav',
#  'cinci_1211d070-2b16-45fa-ac5c-ef3714cc62e9_1.wav',
#  'aprinde_lumina_8ad8eff6-0ffa-4431-ade6-8d8281514667_2.wav',
#  'doi_3d914c7a-1f27-47c3-8b69-27cb17b33a47_1.wav',
#  'opreste_masina_a08a2d78-422f-4d1b-9f68-96ef61ad4a9a_2.wav',
#  'sase_311e7388-8a20-496f-a997-89e8ae224af8_3.wav',
#  'unu_2f29df7d-5fc9-4556-9098-b85ee20f5e94_3.wav',
# ...

# %%
mapping = {
'sase':';;''][]./;';';'',
'sapte',
'noua',
'porneste masina',
'opreste masina',
'verifica emailul'}
